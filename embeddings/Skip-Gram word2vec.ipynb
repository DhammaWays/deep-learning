# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:22, 379KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
from math import sqrt

#freqWords = Counter(words)
#print(freqWords.most_common(20))
freqWord = Counter(int_words)
def prob_discard(w, t=100000):
    global freqWord
    return 1.0 - sqrt(t/freqWord[w])

# The final subsampled word list
train_words =  [w_i for w_i in int_words if prob_discard(w_i) <= 0.5]
print("Original Length {}, After subsampling {}".format(len(int_words), len(train_words)))
# Out:
# Original Length 16680599, After subsampling 14197133

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
import random
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = random.randint(1, window_size)
    s_i = idx - r
    if( s_i < 0 ):
        s_i = 0
    e_i = idx + r + 1
    if( e_i > len(words) ):
        e_i = len(words)
    
    return words[s_i:idx] + words[idx+1:e_i]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=(None))
    labels = tf.placeholder(tf.int32, shape=(None, 1))

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1.0, 1.0)) 
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding],
                         stddev=1.0 / sqrt(n_embedding)))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros([n_vocab]))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, embed,
                       labels, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 7.1746 0.6557 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 6.0280 0.6707 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.6191 0.6404 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.3876 0.6627 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2016 0.6461 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.1113 0.6413 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.0552 0.6498 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.9360 0.6424 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.7645 0.6615 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.8653 0.6407 sec/batch
# Nearest to also: faire, oakenfold, upgraded, asher, assessments, ostia, communication, feeling,
# Nearest to no: erase, besieging, agents, air, communities, definition, aurelius, departures,
# Nearest to than: syllogism, absent, undeserved, essendon, norske, squad, narrated, messagepad,
# Nearest to by: hill, prevents, alive, accidents, discovery, reappointed, third, ifex,
# Nearest to four: walsh, confederations, kaye, alain, allergic, galilee, dutch, improvement,
# Nearest to with: opposite, permit, unachievable, movement, janusz, birthplace, mishnah, healers,
# Nearest to this: fruition, therapy, treatise, antisemitism, popular, version, loneliness, forming,
# Nearest to more: freestyle, kolbe, entitled, robot, cpu, akm, agree, acid,
# Nearest to nobel: sketching, carter, thomas, hazard, judy, nine, belgium, judenfrage,
# Nearest to powers: asparagales, parker, deep, perfectly, belly, dimers, bodily, scheme,
# Nearest to paris: buying, los, artie, nonstandard, ex, witty, arta, re,
# Nearest to experience: reclusive, hal, apl, admission, captive, towards, ackroyd, oligarchical,
# Nearest to bill: hills, retook, blistering, germanisation, foiled, gabab, spader, afdb,
# Nearest to operating: radiohead, exited, bystander, trading, emphasis, violated, desires, ourselves,
# Nearest to event: cunningham, fusel, helene, interesting, sanction, tories, repel, incursions,
# Nearest to liberal: angola, ung, proposed, insects, keeps, processed, asturias, repeaters,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.9211 0.6720 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.8372 0.6491 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.8081 0.6693 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9419 0.6518 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.8402 0.6698 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.7678 0.6730 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.8639 0.6626 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7727 0.6794 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.8027 0.6556 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.7576 0.6861 sec/batch
# Nearest to also: faire, avl, rum, oakenfold, singh, acquiring, pakistan, upgraded,
# Nearest to no: sprayed, erase, besieging, departures, peachtree, alembic, unveils, tuft,
# Nearest to than: convertible, absent, syllogism, squad, anabaptist, norske, mariners, undeserved,
# Nearest to by: armadillo, eca, amphetamines, inferences, hill, mil, earned, icd,
# Nearest to four: zero, walsh, anteater, improvement, multitude, cpc, ashby, alain,
# Nearest to with: mishnah, kylie, unachievable, incompressible, dma, okay, wiles, movement,
# Nearest to this: fruition, treatise, antisemitism, therapy, asterix, loneliness, antidote, bastard,
# Nearest to more: amnesiac, agree, appetite, photoshop, bloodstream, motivating, entitled, castille,
# Nearest to nobel: sketching, standings, judy, bp, hazard, smoothness, carter, portage,
# Nearest to powers: asparagales, deep, parker, gollum, morey, mandamus, perfectly, belly,
# Nearest to paris: buying, artie, los, pseudoscientific, witty, knighted, nine, ex,
# Nearest to experience: reclusive, thoroughfare, featureless, aeons, chandigarh, hal, cornered, oligarchical,
# Nearest to bill: blistering, retook, doubled, foiled, hills, colourful, zygmunt, majestic,
# Nearest to operating: bystander, aimee, radiohead, emphasis, trading, kahan, peredeo, categorization,
# Nearest to event: tories, fusel, cunningham, helene, tanna, slice, interesting, dismal,
# Nearest to liberal: ung, angola, proposed, keeps, delivers, processed, insects, dernier,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.7075 0.6811 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8129 0.6923 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.7825 0.6822 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.7814 0.6810 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8083 0.6974 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8624 0.6912 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7133 0.7243 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7718 0.7017 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7767 0.7222 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7915 0.7226 sec/batch
# Nearest to also: avl, faire, oakenfold, battenberg, upgraded, highbury, communication, remy,
# Nearest to no: erase, sprayed, besieging, alembic, peachtree, departures, tuft, air,
# Nearest to than: convertible, absent, norske, operetta, zakim, undeserved, syllogism, rhonda,
# Nearest to by: reappointed, disraeli, prevents, hill, eca, amphetamines, insistent, sackville,
# Nearest to four: ashby, barnabas, bricklin, westheimer, comedians, cocker, deutsche, trolls,
# Nearest to with: unachievable, kylie, healers, ballpoint, protestors, occultation, constitutionality, travolta,
# Nearest to this: fruition, treatise, popular, antisemitism, loneliness, transcriptional, bastard, kraken,
# Nearest to more: castille, agree, malay, amnesiac, acid, wreckage, appetite, photoshop,
# Nearest to nobel: sketching, grinder, thomas, judenfrage, judy, fine, portage, hazard,
# Nearest to powers: asparagales, parker, deep, gollum, morey, mandamus, belly, pacifica,
# Nearest to paris: artie, buying, pseudoscientific, eurocard, droit, los, hannes, thyssen,
# Nearest to experience: featureless, chandigarh, hipper, reclusive, solvent, graduates, heuvelmans, cornered,
# Nearest to bill: blistering, foiled, retook, girdler, tlatoani, majestic, workbench, doubled,
# Nearest to operating: aimee, bystander, radiohead, seri, emphasis, kahan, odum, peredeo,
# Nearest to event: tories, fusel, capuchin, sanction, helene, dismal, interesting, being,
# Nearest to liberal: disraeli, bt, barnabas, balalaika, curve, boron, iq, horizon,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7058 0.7133 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.6439 0.7270 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7152 0.7051 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6681 0.7240 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.4886 0.7277 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6629 0.7081 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7135 0.7337 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6249 0.7143 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6435 0.7333 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6632 0.7343 sec/batch
# Nearest to also: faire, avl, upgraded, constraint, doubleheader, battenberg, countable, feeling,
# Nearest to no: erase, besieging, alembic, departures, sprayed, air, believing, tuft,
# Nearest to than: convertible, absent, operetta, syllogism, pos, zakim, selecting, undeserved,
# Nearest to by: krantz, reappointed, cebit, disraeli, armadillo, circumcised, amphetamines, bloemfontein,
# Nearest to four: zero, castiglione, einaudi, walsh, shoddy, sentient, three, barnabas,
# Nearest to with: cerium, clausewitz, interregnum, ballpoint, wands, kylie, reichswehr, unachievable,
# Nearest to this: benchers, fruition, therapy, consequentialism, loneliness, transcriptional, antisemitism, treatise,
# Nearest to more: freestyle, castille, agree, nontheism, motivating, cpu, most, oils,
# Nearest to nobel: sketching, portage, grinder, arbitrator, thomas, ringen, judy, judenfrage,
# Nearest to powers: gollum, deep, asparagales, mandamus, parker, belly, perfectly, pacifica,
# Nearest to paris: buying, artie, hannes, thyssen, los, unpowered, eurocard, dahalo,
# Nearest to experience: featureless, chandigarh, graduates, heuvelmans, hipper, solvent, towards, admission,
# Nearest to bill: blistering, foiled, retook, girdler, workbench, cheers, doubled, majestic,
# Nearest to operating: aimee, bystander, radiohead, seri, emphasis, kahan, boot, peredeo,
# Nearest to event: helene, tories, being, sanction, tanna, dismal, sidespin, charcoal,
# Nearest to liberal: insects, something, delivers, brooklands, mentored, ung, iq, restructuring,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6752 0.7148 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6711 0.7321 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.7129 0.7119 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6592 0.7262 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6696 0.7332 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6570 0.7041 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.6459 0.7319 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.6259 0.7126 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.6107 0.7285 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.5989 0.7347 sec/batch
# Nearest to also: faire, avl, upgraded, doubleheader, ostia, handhelds, lonsdaleite, oakenfold,
# Nearest to no: erase, departures, besieging, air, alembic, lika, sprayed, peachtree,
# Nearest to than: convertible, absent, syllogism, zakim, pos, cornets, norske, undeserved,
# Nearest to by: disraeli, cebit, reappointed, cleartype, insistent, krantz, pandit, initiatives,
# Nearest to four: zero, cru, nine, three, eight, bassoonist, cam, six,
# Nearest to with: clausewitz, interregnum, cerium, ballpoint, okay, crono, occultation, dupin,
# Nearest to this: benchers, consequentialism, fruition, kom, it, therapy, velikovsky, drunkenness,
# Nearest to more: oils, castille, theosophists, motivating, pili, appetite, wreckage, freestyle,
# Nearest to nobel: sketching, bakelite, thomas, doi, ringen, portage, grinder, abkhazians,
# Nearest to powers: gollum, parker, mandamus, congregationalism, asparagales, morey, belly, pacifica,
# Nearest to paris: buying, artie, knighted, dahalo, thyssen, hannes, los, unpowered,
# Nearest to experience: featureless, eutyches, reclusive, heuvelmans, graduates, cornered, chandigarh, admission,
# Nearest to bill: blistering, foiled, retook, tlatoani, workbench, girdler, please, majestic,
# Nearest to operating: aimee, radiohead, bystander, seri, trading, peredeo, boot, emphasis,
# Nearest to event: sanction, tories, slice, tanna, helene, sidespin, dismal, charcoal,
# Nearest to liberal: insects, something, delivers, wronged, impractical, iq, fearsome, jekyll,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.6668 0.7205 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.5312 0.7387 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.6393 0.7220 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.6116 0.7253 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.5487 0.7406 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.6431 0.7160 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.6083 0.7568 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.5998 0.7264 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.6130 0.7193 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.6110 0.7392 sec/batch
# Nearest to also: faire, avl, ostia, doubleheader, upgraded, lazio, feeling, celestines,
# Nearest to no: erase, departures, air, lika, cautious, besieging, sprayed, tuft,
# Nearest to than: convertible, syllogism, absent, rhonda, cornets, norske, undeserved, zakim,
# Nearest to by: disraeli, cebit, syriac, reappointed, cleartype, insistent, krantz, demeter,
# Nearest to four: nine, zero, three, eight, drachmae, two, bassoonist, dor,
# Nearest to with: ballpoint, ducati, dune, clausewitz, schwitters, interregnum, weightings, krulak,
# Nearest to this: benchers, consequentialism, a, prion, therapy, fruition, treatise, it,
# Nearest to more: theosophists, oils, castille, freestyle, polypeptides, appetite, malay, motivating,
# Nearest to nobel: sketching, thomas, fine, ringen, portage, zeng, judenfrage, barenaked,
# Nearest to powers: gollum, mandamus, belly, asparagales, parker, morey, congregationalism, pacifica,
# Nearest to paris: buying, artie, dahalo, thyssen, conspiracy, pom, unpowered, knighted,
# Nearest to experience: featureless, eutyches, reclusive, heuvelmans, chandigarh, hipper, solvent, hal,
# Nearest to bill: blistering, girdler, retook, tlatoani, foiled, afdb, zygmunt, germanisation,
# Nearest to operating: aimee, radiohead, seri, trading, bystander, emphasis, odum, albino,
# Nearest to event: helene, screwing, tanna, destry, tories, sidespin, propeller, sanction,
# Nearest to liberal: insects, delivers, something, wronged, restructuring, mentored, brooklands, iq,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.5549 0.7166 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.4302 0.7385 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.5697 0.7332 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.4886 0.7057 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.5941 0.7088 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.5913 0.6797 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.5757 0.7125 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.5792 0.6928 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.6178 0.6972 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.5509 0.7070 sec/batch
# Nearest to also: elgar, faire, avl, unfettered, biathlon, lazio, ostia, pakistan,
# Nearest to no: erase, lika, rivero, peachtree, believing, gavrilo, rosebud, legio,
# Nearest to than: convertible, absent, syllogism, rhonda, norske, undeserved, jams, martinus,
# Nearest to by: erfurt, disraeli, cebit, cleartype, exeter, edif, ducati, durian,
# Nearest to four: nine, zero, three, eight, two, six, drachmae, seven,
# Nearest to with: ducati, ballpoint, dupin, clausewitz, dune, schwitters, weightings, brubeck,
# Nearest to this: benchers, it, a, nitrox, loneliness, velikovsky, consequentialism, therapy,
# Nearest to more: theosophists, appetite, nitrox, castille, polypeptides, minimised, malay, most,
# Nearest to nobel: sketching, fine, ringen, thomas, portage, judenfrage, cannibalistic, leopard,
# Nearest to powers: gollum, mandamus, asparagales, parker, morey, belly, constitutions, alden,
# Nearest to paris: buying, knighted, artie, dahalo, thyssen, unpowered, conspiracy, pseudoscientific,
# Nearest to experience: featureless, eutyches, reclusive, solvent, chandigarh, admission, heuvelmans, graduates,
# Nearest to bill: blistering, retook, girdler, zygmunt, wait, germanisation, ats, tlatoani,
# Nearest to operating: aimee, seri, radiohead, bystander, emphasis, trading, wilkes, resistor,
# Nearest to event: helene, screwing, sidespin, destry, slice, propeller, wavered, pcbs,
# Nearest to liberal: conservative, wronged, insects, something, delivers, mentored, restructuring, landless,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.5235 0.6878 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.6074 0.7086 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.4687 0.6855 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.5216 0.7057 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.5848 0.7057 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.5027 0.6894 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.6045 0.7056 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.5574 0.6782 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.5444 0.7057 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.5298 0.6876 sec/batch
# Nearest to also: faire, avl, doubleheader, elgar, feeling, glissandi, biathlon, pakistan,
# Nearest to no: sprayed, departures, cautious, erase, extradited, jargon, plea, rivero,
# Nearest to than: convertible, absent, norske, zakim, misdemeanors, undeserved, syllogism, disraeli,
# Nearest to by: durian, disraeli, cleartype, erfurt, aha, fridtjof, exeter, edif,
# Nearest to four: zero, three, nine, two, eight, five, six, gem,
# Nearest to with: ducati, cerium, ballpoint, clausewitz, topol, schwitters, falsity, microstates,
# Nearest to this: a, it, benchers, which, popular, freya, nitrox, excitotoxins,
# Nearest to more: malay, theosophists, freestyle, nitrox, appetite, wreckage, castille, most,
# Nearest to nobel: sketching, ringen, fine, thomas, portage, zeng, hazard, paw,
# Nearest to powers: morey, parker, asparagales, mandamus, belly, constitutions, held, civilized,
# Nearest to paris: buying, knighted, artie, et, deutschen, thyssen, dahalo, pseudoscientific,
# Nearest to experience: featureless, eutyches, reclusive, heuvelmans, chandigarh, admission, solvent, potentially,
# Nearest to bill: blistering, retook, tlatoani, afdb, clementine, zygmunt, foiled, monarchic,
# Nearest to operating: aimee, boot, albino, emphasis, seri, resistor, bystander, trading,
# Nearest to event: screwing, helene, sidespin, destry, slice, wavered, eleusinian, tories,
# Nearest to liberal: wronged, conservative, delivers, something, iq, restructuring, insects, fabius,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.4317 0.7048 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.5638 0.7091 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.5385 0.7712 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.5972 0.7858 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.5986 0.7583 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.5620 0.7211 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.5648 0.7715 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.5426 0.7116 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.4809 0.7257 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.5722 0.7316 sec/batch
# Nearest to also: glissandi, faire, unfettered, elgar, list, doubleheader, wobegon, handhelds,
# Nearest to no: sprayed, departures, plea, sang, neutralist, cautious, rivero, dromedary,
# Nearest to than: operetta, convertible, vian, absent, misdemeanors, pos, syllogism, cornets,
# Nearest to by: erfurt, grindcore, jagan, sparse, insistent, cleartype, disraeli, durian,
# Nearest to four: three, eight, zero, nine, two, six, five, seven,
# Nearest to with: ducati, herc, falsity, rref, clausewitz, travolta, krulak, weightings,
# Nearest to this: it, a, benchers, nitrox, freya, popular, hosea, therapy,
# Nearest to more: freestyle, nitrox, malay, most, gopher, minimised, theosophists, less,
# Nearest to nobel: sketching, ringen, fine, thomas, prize, portage, praeger, paw,
# Nearest to powers: constitutions, mandamus, morey, parker, asparagales, belly, gollum, congregationalism,
# Nearest to paris: buying, thyssen, knighted, et, deutschen, artie, dahalo, mussorgsky,
# Nearest to experience: featureless, eutyches, reclusive, chandigarh, heuvelmans, admission, glagolitic, potentially,
# Nearest to bill: blistering, retook, tlatoani, clementine, zygmunt, germanisation, girdler, wait,
# Nearest to operating: aimee, bystander, gui, boot, albino, clift, waco, resistor,
# Nearest to event: helene, screwing, eleusinian, quadra, destry, sidespin, wavered, tories,
# Nearest to liberal: delivers, conservative, something, wronged, insects, restructuring, mentored, brooklands,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 4.5338 0.6957 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 4.5619 0.7204 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 4.5319 0.6854 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 4.5410 0.7155 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.5382 0.7069 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.5341 0.6921 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.5724 0.7180 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.5657 0.6875 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.3557 0.7228 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.5414 0.7078 sec/batch
# Nearest to also: list, glissandi, unfettered, biathlon, avl, wobegon, dhea, glycolytic,
# Nearest to no: neutralist, sprayed, cammag, wrongfully, nitroglycerin, sang, dromedary, sinaiticus,
# Nearest to than: convertible, misdemeanors, operetta, absent, vian, syllogism, pos, norske,
# Nearest to by: durian, grindcore, jagan, cleartype, camelcase, bloemfontein, bitola, disraeli,
# Nearest to four: three, eight, six, two, zero, nine, five, seven,
# Nearest to with: rref, herc, widths, cerium, ducati, falsity, dupin, weightings,
# Nearest to this: it, a, hosea, which, nitrox, rennet, deprogramming, that,
# Nearest to more: most, freestyle, less, malay, theosophists, nitrox, minimised, gopher,
# Nearest to nobel: sketching, fine, thomas, prize, praeger, ringen, paw, portage,
# Nearest to powers: belly, mandamus, asparagales, constitutions, parker, morey, dimers, gollum,
# Nearest to paris: buying, thyssen, knighted, et, dahalo, deutschen, artie, los,
# Nearest to experience: featureless, eutyches, reclusive, admission, chandigarh, heuvelmans, solvent, potentially,
# Nearest to bill: blistering, girdler, retook, weightlessness, germanisation, ridicule, tlatoani, previously,
# Nearest to operating: aimee, gui, sierpinski, resistor, wilkes, codeword, consisted, cuitl,
# Nearest to event: screwing, helene, eleusinian, sidespin, quadra, tories, clinging, wavered,
# Nearest to liberal: wronged, delivers, something, conservative, vests, mentored, insects, brooklands,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.5253 0.7387 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.4774 0.7435 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.5147 0.7153 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.4824 0.7464 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.5020 0.7362 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.4827 0.7243 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.1929 0.7397 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.2528 0.7103 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.2938 0.7396 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.3474 0.7391 sec/batch
# Nearest to also: glissandi, elgar, feeling, doubleheader, entropy, faire, revitalized, list,
# Nearest to no: sang, wrongfully, tim, phane, cammag, nitroglycerin, sinaiticus, samurai,
# Nearest to than: absent, misdemeanors, operetta, cornets, inhalant, vian, syllogism, cromwell,
# Nearest to by: jagan, disraeli, grindcore, sqrat, erfurt, cleartype, suras, reappointed,
# Nearest to four: three, six, nine, eight, five, zero, two, seven,
# Nearest to with: krulak, rref, ducati, dupin, boitano, clausewitz, birley, herc,
# Nearest to this: it, a, hosea, which, blowfish, rennet, that, commentaries,
# Nearest to more: most, freestyle, less, larger, theseus, gopher, malay, nitrox,
# Nearest to nobel: prize, sketching, physiology, leopard, thomas, ringen, praeger, zeng,
# Nearest to powers: mandamus, belly, parker, constitutions, morey, asparagales, gollum, dimers,
# Nearest to paris: buying, knighted, los, thyssen, et, deutschen, urbain, mussorgsky,
# Nearest to experience: reclusive, eutyches, featureless, heuvelmans, admission, chandigarh, deprogrammings, glagolitic,
# Nearest to bill: blistering, girdler, retook, tlatoani, germanisation, ridicule, clementine, masashi,
# Nearest to operating: aimee, gui, bystander, consisted, cuitl, wilkes, toxin, clift,
# Nearest to event: screwing, helene, tories, eleusinian, quadra, clinging, wavered, sidespin,
# Nearest to liberal: conservative, something, wronged, delivers, vests, mentored, jekyll, landless,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.4562 0.7208 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.4993 0.7401 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.5225 0.7216 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.5046 0.7350 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.6127 0.7394 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.5799 0.7090 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 4.5768 0.7406 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 4.5381 0.7228 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 4.5285 0.7295 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 4.3263 0.7449 sec/batch
# Nearest to also: list, entropy, glissandi, dhea, wobegon, doubleheader, biathlon, mondeo,
# Nearest to no: neutralist, wrongfully, nitroglycerin, sang, favourable, aboriginal, dromedary, sinaiticus,
# Nearest to than: norske, planting, clarifies, misdemeanors, more, inhalant, absent, superjanet,
# Nearest to by: jagan, in, bitola, sqrat, which, durian, grindcore, disraeli,
# Nearest to four: three, eight, five, nine, six, two, zero, seven,
# Nearest to with: in, rref, kurds, falsity, interregnum, between, zero, herc,
# Nearest to this: it, a, which, kaddish, that, nitrox, deprogramming, lopez,
# Nearest to more: most, less, larger, malay, polypeptides, theosophists, nitrox, minimised,
# Nearest to nobel: prize, sketching, physiology, ringen, leopard, praeger, zeng, respiratory,
# Nearest to powers: belly, mandamus, asparagales, parker, deep, dimers, gollum, emsworth,
# Nearest to paris: buying, deutschen, los, thyssen, et, mussorgsky, knighted, urbain,
# Nearest to experience: eutyches, featureless, reclusive, heuvelmans, admission, solvent, glagolitic, deprogrammings,
# Nearest to bill: blistering, girdler, tlatoani, retook, ridicule, clementine, assassinate, zygmunt,
# Nearest to operating: aimee, gui, consisted, many, sierpinski, resistor, cuitl, waco,
# Nearest to event: screwing, quadra, tories, helene, eleusinian, sidespin, wavered, pcbs,
# Nearest to liberal: conservative, political, something, impractical, vests, wronged, delivers, restructuring,
# Epoch 1/10 Iteration: 12100 Avg. Training loss: 4.4899 0.7222 sec/batch
# Epoch 1/10 Iteration: 12200 Avg. Training loss: 4.5419 0.7433 sec/batch
# Epoch 1/10 Iteration: 12300 Avg. Training loss: 4.5493 0.7303 sec/batch
# Epoch 1/10 Iteration: 12400 Avg. Training loss: 4.6062 0.7290 sec/batch
# Epoch 1/10 Iteration: 12500 Avg. Training loss: 4.5099 0.7439 sec/batch
# Epoch 1/10 Iteration: 12600 Avg. Training loss: 4.5962 0.7147 sec/batch
# Epoch 1/10 Iteration: 12700 Avg. Training loss: 4.4801 0.7417 sec/batch
# Epoch 1/10 Iteration: 12800 Avg. Training loss: 4.5767 0.7316 sec/batch
# Epoch 1/10 Iteration: 12900 Avg. Training loss: 4.3774 0.7173 sec/batch
# Epoch 1/10 Iteration: 13000 Avg. Training loss: 4.2507 0.7445 sec/batch
# Nearest to also: list, mali, glissandi, dhea, scalia, mauritius, pakistan, acetaldehyde,
# Nearest to no: nitroglycerin, wrongfully, smectic, sang, cammag, sinaiticus, scarcely, neutralist,
# Nearest to than: norske, essendon, convertible, misdemeanors, inhalant, undeserved, lilian, more,
# Nearest to by: jagan, in, which, three, eight, two, zero, grindcore,
# Nearest to four: three, five, eight, two, six, seven, zero, nine,
# Nearest to with: in, interregnum, herc, between, rhodesian, dupin, birley, dalnet,
# Nearest to this: it, which, a, kaddish, nitrox, that, bastard, demographic,
# Nearest to more: most, less, malay, larger, rather, nitrox, theosophists, macedonian,
# Nearest to nobel: prize, sketching, leopard, physiology, praeger, fine, ringen, zeng,
# Nearest to powers: belly, asparagales, mandamus, parker, kildall, emsworth, dimers, morey,
# Nearest to paris: buying, et, deutschen, los, thyssen, knighted, mussorgsky, urbain,
# Nearest to experience: eutyches, featureless, reclusive, solvent, admission, hyperinsulinism, rancid, hydroxy,
# Nearest to bill: blistering, girdler, retook, ridicule, tlatoani, clementine, zygmunt, cry,
# Nearest to operating: aimee, gui, clift, windows, tojo, eddowes, bystander, jester,
# Nearest to event: screwing, quadra, tories, helene, pri, eleusinian, clinging, provable,
# Nearest to liberal: conservative, labour, vests, tryst, cana, gwp, libertarian, restructuring,
# Epoch 1/10 Iteration: 13100 Avg. Training loss: 4.5129 0.7236 sec/batch
# Epoch 1/10 Iteration: 13200 Avg. Training loss: 4.4952 0.7661 sec/batch
# Epoch 1/10 Iteration: 13300 Avg. Training loss: 4.3559 0.7411 sec/batch
# Epoch 1/10 Iteration: 13400 Avg. Training loss: 4.4571 0.7137 sec/batch
# Epoch 1/10 Iteration: 13500 Avg. Training loss: 4.4957 0.7417 sec/batch
# Epoch 1/10 Iteration: 13600 Avg. Training loss: 4.4893 0.7532 sec/batch
# Epoch 1/10 Iteration: 13700 Avg. Training loss: 4.4946 0.7456 sec/batch
# Epoch 1/10 Iteration: 13800 Avg. Training loss: 4.4310 0.7181 sec/batch
# Epoch 1/10 Iteration: 13900 Avg. Training loss: 4.4605 0.6872 sec/batch
# Epoch 1/10 Iteration: 14000 Avg. Training loss: 4.5287 0.7167 sec/batch
# Nearest to also: list, glissandi, mali, unfettered, elgar, acetaldehyde, biathlon, dhea,
# Nearest to no: nitroglycerin, scarcely, sang, wrongfully, sooner, sinaiticus, evidence, smectic,
# Nearest to than: undeserved, inhalant, syllogism, norske, lilian, horoscope, convertible, cornets,
# Nearest to by: grindcore, durian, jagan, cleartype, efe, sqrat, disraeli, shatz,
# Nearest to four: three, five, six, eight, zero, two, seven, jan,
# Nearest to with: dupin, falsity, ducati, rref, clausewitz, birley, interregnum, ffts,
# Nearest to this: it, which, kaddish, a, nitrox, deprogramming, that, benchers,
# Nearest to more: less, most, larger, malay, rather, polypeptides, freestyle, cpu,
# Nearest to nobel: prize, ringen, physiology, zeng, sketching, leopard, fine, praeger,
# Nearest to powers: belly, mandamus, asparagales, constitutions, parker, emsworth, gollum, congregationalism,
# Nearest to paris: buying, los, et, thyssen, deutschen, mussorgsky, knighted, pom,
# Nearest to experience: eutyches, reclusive, featureless, hyperinsulinism, admission, deprogrammings, solvent, chandigarh,
# Nearest to bill: blistering, girdler, cry, puckett, ridicule, tlatoani, retook, zygmunt,
# Nearest to operating: gui, aimee, beos, clift, resistor, mac, fox, consisted,
# Nearest to event: screwing, helene, tories, quadra, eleusinian, clinging, pri, incursions,
# Nearest to liberal: conservative, vests, wronged, gwp, restructuring, jekyll, delivers, intentionality,
# Epoch 1/10 Iteration: 14100 Avg. Training loss: 4.5567 0.7105 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.5384 0.0226 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.4728 0.7279 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.4224 0.6880 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.4605 0.7205 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.5119 0.7001 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.3949 0.7139 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.4659 0.7166 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.4426 0.6919 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.3812 0.7208 sec/batch
# Nearest to also: list, glissandi, hamad, mali, acetaldehyde, unfettered, baybears, cantigas,
# Nearest to no: scarcely, evidence, sang, tim, sooner, codomain, conflated, wrongfully,
# Nearest to than: absent, inhalant, syllogism, misdemeanors, norske, undeserved, operetta, horoscope,
# Nearest to by: grindcore, sparse, syriac, jagan, durian, akston, shatz, suras,
# Nearest to four: eight, three, six, five, two, seven, zero, nine,
# Nearest to with: dupin, minos, rref, interregnum, ducati, clausewitz, lefebvre, falsity,
# Nearest to this: it, which, a, kaddish, hosea, eschatology, marshallese, nitrox,
# Nearest to more: less, larger, most, rather, nontheism, polypeptides, appetite, much,
# Nearest to nobel: prize, physiology, ringen, sketching, praeger, zeng, tauris, economist,
# Nearest to powers: mandamus, asparagales, constitutions, parker, belly, gollum, knicks, dimers,
# Nearest to paris: buying, et, thyssen, los, deutschen, knighted, re, mussorgsky,
# Nearest to experience: eutyches, reclusive, heuvelmans, featureless, solvent, admission, rancid, edgbaston,
# Nearest to bill: blistering, tlatoani, zygmunt, girdler, cry, puckett, retook, ridicule,
# Nearest to operating: gui, aimee, beos, bystander, clift, consisted, ximinez, fox,
# Nearest to event: screwing, helene, tories, quadra, minos, pri, eleusinian, pcbs,
# Nearest to liberal: conservative, wronged, delivers, impractical, intentionality, restructuring, vests, gwp,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.3703 0.7275 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.3830 0.7360 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.4445 0.7388 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.4226 0.7130 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.4289 0.7385 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.4265 0.7259 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.4652 0.7348 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.4754 0.7411 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.4593 0.7167 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.4201 0.7435 sec/batch
# Nearest to also: list, glissandi, hamad, filings, cantigas, singh, acetaldehyde, abbeville,
# Nearest to no: scarcely, wrongfully, codomain, evidence, smectic, nitroglycerin, karabiners, tim,
# Nearest to than: inhalant, syllogism, operetta, norske, misdemeanors, more, convertible, feroze,
# Nearest to by: durian, karpov, grindcore, anchorage, sparse, cleartype, duodecimal, jagan,
# Nearest to four: three, six, five, eight, two, seven, zero, nine,
# Nearest to with: adhesives, rref, dupin, birley, minos, ducati, microvision, widths,
# Nearest to this: it, which, kaddish, a, that, nitrox, marshallese, hgp,
# Nearest to more: less, larger, most, rather, faster, appetite, much, fewer,
# Nearest to nobel: prize, ringen, praeger, sketching, zeng, leopard, physiology, tauris,
# Nearest to powers: mandamus, constitutions, asparagales, parker, brigade, dimers, belly, morey,
# Nearest to paris: buying, los, thyssen, et, deutschen, knighted, mussorgsky, hannes,
# Nearest to experience: eutyches, reclusive, featureless, heuvelmans, admission, chandigarh, keeping, deprogrammings,
# Nearest to bill: blistering, tlatoani, girdler, insure, substitutable, zygmunt, cry, previously,
# Nearest to operating: gui, aimee, clift, beos, sierpinski, resistor, boot, ximinez,
# Nearest to event: screwing, tories, helene, quadra, eleusinian, pri, clinging, sidespin,
# Nearest to liberal: conservative, wronged, delivers, impractical, vests, restructuring, mps, jekyll,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.4585 0.7426 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.4559 0.7242 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.2584 0.7471 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.4783 0.7166 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.4792 0.7441 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.4877 0.7383 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.4676 0.7236 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.4757 0.7469 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.4234 0.7208 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.4484 0.7440 sec/batch
# Nearest to also: glissandi, cantigas, list, filings, tanning, mcnab, tauranac, unfettered,
# Nearest to no: scarcely, codomain, sang, tim, evidence, wrongfully, karabiners, cammag,
# Nearest to than: operetta, syllogism, inhalant, more, absent, cornets, misdemeanors, planets,
# Nearest to by: grindcore, durian, karpov, jagan, cleartype, shatz, insistent, efe,
# Nearest to four: three, two, six, five, eight, seven, nine, zero,
# Nearest to with: rref, ducati, dupin, interregnum, macrobiotics, krulak, minos, cerium,
# Nearest to this: it, which, a, kaddish, that, nitrox, popular, eschatology,
# Nearest to more: less, larger, most, rather, appetite, faster, fewer, sacrum,
# Nearest to nobel: prize, ringen, praeger, zeng, sketching, bakelite, pimp, leopard,
# Nearest to powers: mandamus, asparagales, belly, constitutions, gollum, parker, morey, dimers,
# Nearest to paris: et, buying, los, thyssen, knighted, deutschen, mussorgsky, hannes,
# Nearest to experience: eutyches, reclusive, featureless, admission, heuvelmans, deprogrammings, rancid, keeping,
# Nearest to bill: blistering, girdler, tlatoani, ridicule, previously, substitutable, greig, puckett,
# Nearest to operating: gui, beos, aimee, sierpinski, clift, boot, resistor, codeword,
# Nearest to event: screwing, tories, helene, eleusinian, quadra, minos, pri, pcbs,
# Nearest to liberal: conservative, gwp, mps, maasai, delivers, eplf, party, grindcore,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.5043 0.7538 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.4873 0.7162 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.4333 0.7445 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.3966 0.7258 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.4512 0.7396 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.3768 0.7448 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.1650 0.7172 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.4071 0.7520 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.5113 0.7381 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.3934 0.7281 sec/batch
# Nearest to also: list, glissandi, cantigas, filings, bt, boron, tanning, fullerenes,
# Nearest to no: evidence, scarcely, codomain, tim, wrongfully, sang, aboriginal, conflated,
# Nearest to than: syllogism, operetta, more, inhalant, cornets, or, equ, but,
# Nearest to by: grindcore, wereman, jagan, durian, sparse, camelcase, shatz, efe,
# Nearest to four: three, five, six, eight, two, nine, seven, zero,
# Nearest to with: rref, ffts, in, lefebvre, falsity, krulak, microvision, between,
# Nearest to this: it, which, a, kaddish, popular, nitrox, that, prion,
# Nearest to more: less, larger, most, rather, appetite, faster, fewer, nontheism,
# Nearest to nobel: prize, ringen, praeger, sketching, fine, leopard, bakelite, tauris,
# Nearest to powers: constitutions, mandamus, asparagales, brigade, gollum, morey, parker, knicks,
# Nearest to paris: et, los, buying, thyssen, deutschen, mussorgsky, hannes, knighted,
# Nearest to experience: eutyches, reclusive, featureless, admission, keeping, deprogrammings, solvent, rancid,
# Nearest to bill: blistering, tlatoani, zygmunt, planter, substitutable, sunnyvale, girdler, sqq,
# Nearest to operating: gui, beos, boot, ximinez, clift, aimee, sierpinski, desires,
# Nearest to event: tories, screwing, period, eleusinian, helene, quadra, era, sidespin,
# Nearest to liberal: conservative, mps, delivers, wronged, gwp, vests, insects, jekyll,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.4200 0.7539 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.4112 0.7185 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.4402 0.7457 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.3294 0.7502 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.5141 0.7162 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.5083 0.7437 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.4925 0.7168 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.4663 0.7064 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.4404 0.7122 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.4517 0.6820 sec/batch
# Nearest to also: list, glissandi, baybears, that, sometimes, ilm, bt, maasai,
# Nearest to no: evidence, scarcely, codomain, sang, conflated, wrongfully, complexities, sooner,
# Nearest to than: syllogism, inhalant, laura, more, operetta, much, schlei, feroze,
# Nearest to by: shatz, in, grindcore, durian, which, efe, cleartype, meritocratic,
# Nearest to four: five, three, six, eight, two, nine, seven, cet,
# Nearest to with: rref, ffts, minos, between, microvision, falsity, ducati, bt,
# Nearest to this: which, it, kaddish, a, popular, nitrox, that, hgp,
# Nearest to more: less, most, larger, rather, faster, appetite, fewer, stronger,
# Nearest to nobel: prize, ringen, praeger, tauris, bakelite, sketching, physiology, leopard,
# Nearest to powers: mandamus, constitutions, congregationalism, asparagales, brigade, morey, parker, gollum,
# Nearest to paris: et, los, buying, deutschen, re, thyssen, knighted, hannes,
# Nearest to experience: featureless, reclusive, eutyches, keeping, deprogrammings, admission, mallon, wikipedia,
# Nearest to bill: blistering, zygmunt, tlatoani, substitutable, previously, planter, girdler, ridicule,
# Nearest to operating: gui, beos, clift, aimee, boot, uns, albino, ximinez,
# Nearest to event: tories, screwing, eleusinian, era, quadra, helene, period, incursions,
# Nearest to liberal: mps, wronged, conservative, insects, something, vests, delivers, phallus,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.4109 0.7246 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.4793 0.6838 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.4821 0.7130 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.3662 0.7108 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.4601 0.6921 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.4335 0.7133 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.3899 0.6835 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.4416 0.7109 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.4363 0.6921 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.4661 0.7320 sec/batch
# Nearest to also: list, baybears, rave, putatively, doubleheader, mcnab, glissandi, that,
# Nearest to no: sang, evidence, wrongfully, tim, codomain, scarcely, sheedy, conflated,
# Nearest to than: syllogism, much, operetta, more, or, but, inhalant, absent,
# Nearest to by: karpov, mouseketeers, krantz, sparse, which, edif, jagan, efe,
# Nearest to four: five, three, six, eight, two, nine, seven, zero,
# Nearest to with: rref, dupin, microvision, birley, kylie, unforgiven, ronstadt, saffron,
# Nearest to this: it, which, a, that, popular, kaddish, nitrox, his,
# Nearest to more: less, larger, most, rather, faster, stronger, fewer, appetite,
# Nearest to nobel: prize, sketching, ringen, bakelite, tauris, praeger, fine, yaound,
# Nearest to powers: mandamus, constitutions, congregationalism, asparagales, brigade, gollum, morey, speculations,
# Nearest to paris: los, buying, mussorgsky, et, knighted, deutschen, re, hernia,
# Nearest to experience: reclusive, eutyches, featureless, admission, deprogrammings, keeping, edgbaston, rancid,
# Nearest to bill: blistering, zygmunt, tlatoani, greig, planter, previously, cry, ridicule,
# Nearest to operating: gui, beos, aimee, clift, boot, unix, uns, kfreebsd,
# Nearest to event: tories, era, screwing, period, helene, quadra, eleusinian, week,
# Nearest to liberal: mps, conservative, wronged, something, delivers, vests, jekyll, democracy,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.4422 0.7200 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.4664 0.6818 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.3924 0.7111 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.2749 0.6889 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.4148 0.7052 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.3600 0.7128 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.4815 0.6919 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.4497 0.7138 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.4305 0.6841 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.4342 0.7130 sec/batch
# Nearest to also: list, acetaldehyde, baybears, that, tanning, ilm, sometimes, which,
# Nearest to no: sang, tim, evidence, wrongfully, codomain, scarcely, complexities, punished,
# Nearest to than: syllogism, operetta, more, much, inhalant, flapping, feroze, absent,
# Nearest to by: efe, jagan, karpov, erfurt, sqrat, mouseketeers, sparse, which,
# Nearest to four: three, five, six, eight, two, seven, nine, zero,
# Nearest to with: rref, microvision, dupin, birley, macrobiotics, between, saffron, interregnum,
# Nearest to this: which, it, a, kaddish, that, popular, mng, ddr,
# Nearest to more: less, most, larger, rather, faster, stronger, fewer, overtly,
# Nearest to nobel: prize, praeger, sketching, fine, ringen, tauris, yaound, ve,
# Nearest to powers: mandamus, constitutions, moires, congregationalism, asparagales, brigade, parker, measures,
# Nearest to paris: buying, mussorgsky, los, thyssen, hernia, et, knighted, hannes,
# Nearest to experience: reclusive, featureless, eutyches, admission, paradigm, keeping, chandigarh, cosets,
# Nearest to bill: blistering, zygmunt, previously, ridicule, planter, cry, debbie, tlatoani,
# Nearest to operating: gui, aimee, beos, clift, boot, albino, uns, emphasis,
# Nearest to event: era, screwing, period, tories, blackball, incursions, events, eleusinian,
# Nearest to liberal: mps, conservative, wronged, party, jekyll, tryst, whig, delivers,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 4.4481 0.7101 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 4.3859 0.6908 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 4.3914 0.7167 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 4.4490 0.6849 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.3399 0.7118 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.4004 0.6903 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.4359 0.7016 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.3668 0.7055 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.4649 0.6822 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.4615 0.7098 sec/batch
# Nearest to also: list, baybears, which, tanning, sometimes, that, glissandi, disambiguation,
# Nearest to no: aboriginal, sheedy, broad, rivero, conflated, yangtze, loma, ace,
# Nearest to than: syllogism, much, more, operetta, cornets, planets, inhalant, accurate,
# Nearest to by: sqrat, jagan, mouseketeers, which, starship, efe, erfurt, in,
# Nearest to four: five, three, two, eight, six, nine, seven, zero,
# Nearest to with: rref, birley, falsity, microvision, between, dupin, freespire, widths,
# Nearest to this: it, which, a, kaddish, that, popular, geocoding, clitoridectomy,
# Nearest to more: less, larger, rather, most, faster, stronger, fewer, greater,
# Nearest to nobel: prize, ringen, sketching, tauris, fine, physiology, praeger, zeng,
# Nearest to powers: mandamus, congregationalism, poststructuralism, digesting, gollum, aesthetic, dimers, hugs,
# Nearest to paris: los, buying, et, thyssen, hernia, qualifying, re, morrill,
# Nearest to experience: reclusive, featureless, paradigm, eutyches, keeping, admission, bracewell, despaired,
# Nearest to bill: blistering, previously, planter, ridicule, zygmunt, greig, girdler, dominion,
# Nearest to operating: beos, unix, gui, aimee, clift, boot, system, kfreebsd,
# Nearest to event: era, screwing, period, tories, events, incursions, quadra, eleusinian,
# Nearest to liberal: conservative, wronged, mps, tryst, something, gwp, jekyll, magdalen,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.3913 0.6866 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.3752 0.7113 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 4.2877 0.6990 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 4.4623 0.6928 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 4.4417 0.7243 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 4.4184 0.6916 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 4.4723 0.7191 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 4.4572 0.6954 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 4.4601 0.7022 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 4.4285 0.7131 sec/batch
# ...
# Epoch 8/10 Iteration: 106900 Avg. Training loss: 4.2766 1.3570 sec/batch
# Epoch 8/10 Iteration: 107000 Avg. Training loss: 4.3646 1.3022 sec/batch
# Nearest to also: which, as, sometimes, below, to, that, for, often,
# Nearest to no: info, insubstantial, import, jargon, duplicate, longer, esoteric, irrelevent,
# Nearest to than: much, more, smaller, less, but, or, considerably, likely,
# Nearest to by: in, which, to, when, a, with, as, also,
# Nearest to four: five, three, six, two, seven, eight, zero, nine,
# Nearest to with: in, to, when, while, which, by, for, a,
# Nearest to this: it, that, which, a, another, same, to, but,
# Nearest to more: less, rather, larger, better, fewer, than, greater, most,
# Nearest to nobel: prize, laureate, physiology, peace, recipient, awarded, scientist, actor,
# Nearest to powers: power, abilities, psionic, commission, legislation, empires, reserve, sopra,
# Nearest to paris: france, skyscraper, denis, tienne, lausanne, louvre, london, joseph,
# Nearest to experience: experiences, something, direct, skill, care, sense, graves, gain,
# Nearest to bill: gates, bills, creator, cassady, pubic, mort, criminalization, band,
# Nearest to operating: hardware, windows, system, computer, unix, systems, os, freebsd,
# Nearest to event: events, extinction, era, object, staged, sporting, ethical, horizon,
# Nearest to liberal: liberals, conservative, party, christian, liberalism, maclennan, nazi, evangelical,
# Epoch 8/10 Iteration: 107100 Avg. Training loss: 4.4150 1.3333 sec/batch
# Epoch 8/10 Iteration: 107200 Avg. Training loss: 4.3683 1.3282 sec/batch
# Epoch 8/10 Iteration: 107300 Avg. Training loss: 4.3548 1.2203 sec/batch
# Epoch 8/10 Iteration: 107400 Avg. Training loss: 4.2996 1.3198 sec/batch
# Epoch 8/10 Iteration: 107500 Avg. Training loss: 4.2553 1.2627 sec/batch
# Epoch 8/10 Iteration: 107600 Avg. Training loss: 4.3742 1.3258 sec/batch
# Epoch 8/10 Iteration: 107700 Avg. Training loss: 4.4147 1.2343 sec/batch
# Epoch 8/10 Iteration: 107800 Avg. Training loss: 4.3517 0.9079 sec/batch
# Epoch 8/10 Iteration: 107900 Avg. Training loss: 4.3983 0.8512 sec/batch
# Epoch 8/10 Iteration: 108000 Avg. Training loss: 4.3760 0.8418 sec/batch
# Nearest to also: which, list, for, below, that, sometimes, several, as,
# Nearest to no: longer, little, evidence, there, never, nothing, doubt, already,
# Nearest to than: much, more, less, but, smaller, likely, considerably, or,
# Nearest to by: to, in, which, with, for, this, when, a,
# Nearest to four: three, five, six, two, seven, eight, zero, nine,
# Nearest to with: to, in, while, when, by, for, which, a,
# Nearest to this: which, it, another, that, a, to, however, some,
# Nearest to more: less, rather, larger, most, than, better, fewer, greater,
# Nearest to nobel: prize, laureate, physiology, academy, awarded, honors, recipient, peace,
# Nearest to powers: power, reserve, governor, government, legislation, empires, piercer, secrets,
# Nearest to paris: france, tienne, denis, louvre, cimeti, lausanne, skyscrapers, skyscraper,
# Nearest to experience: experiences, something, knowledge, skill, understanding, sense, pilots, direct,
# Nearest to bill: gates, assent, bills, cassady, pubic, watch, armistead, acad,
# Nearest to operating: unix, hardware, os, systems, postmaster, gallaudet, computers, file,
# Nearest to event: events, extinction, object, probability, meteorite, future, type, era,
# Nearest to liberal: liberals, conservative, christian, party, maclennan, liberalism, esaf, labor,
# Epoch 8/10 Iteration: 108100 Avg. Training loss: 4.4264 0.8635 sec/batch
# Epoch 8/10 Iteration: 108200 Avg. Training loss: 4.2939 0.8920 sec/batch
# Epoch 8/10 Iteration: 108300 Avg. Training loss: 4.3130 0.8857 sec/batch
# Epoch 8/10 Iteration: 108400 Avg. Training loss: 4.4048 0.9201 sec/batch
# Epoch 8/10 Iteration: 108500 Avg. Training loss: 4.3455 0.8563 sec/batch
# Epoch 8/10 Iteration: 108600 Avg. Training loss: 4.3477 0.8508 sec/batch
# Epoch 8/10 Iteration: 108700 Avg. Training loss: 4.3319 0.9539 sec/batch
# Epoch 8/10 Iteration: 108800 Avg. Training loss: 4.3715 0.9363 sec/batch
# Epoch 8/10 Iteration: 108900 Avg. Training loss: 4.4162 0.9655 sec/batch
# Epoch 8/10 Iteration: 109000 Avg. Training loss: 4.3799 0.9187 sec/batch
# Nearest to also: which, below, list, for, that, sometimes, as, see,
# Nearest to no: longer, little, never, evidence, there, nothing, already, still,
# Nearest to than: much, smaller, less, more, considerably, but, likely, slower,
# Nearest to by: in, which, to, that, with, this, for, at,
# Nearest to four: five, three, six, seven, two, eight, nine, zero,
# Nearest to with: to, when, by, in, for, between, which, while,
# Nearest to this: which, another, it, a, that, same, however, an,
# Nearest to more: less, rather, larger, most, better, fewer, than, smaller,
# Nearest to nobel: prize, laureate, awarded, medicine, honors, physiology, academy, chromatin,
# Nearest to powers: empires, legislation, power, psionic, britain, governments, routes, government,
# Nearest to paris: france, denis, moscow, louvre, tienne, lausanne, cimeti, skyscraper,
# Nearest to experience: experiences, skill, direct, something, knowledge, understanding, spiritual, experienced,
# Nearest to bill: pubic, assent, occlusion, bills, meiji, commons, reproduce, removable,
# Nearest to operating: hardware, unix, os, metro, systems, liner, microkernel, windowing,
# Nearest to event: events, extinction, object, triassic, occur, probability, meteorite, tunguska,
# Nearest to liberal: conservative, liberals, christian, liberalism, maclennan, party, prime, social,
# Epoch 8/10 Iteration: 109100 Avg. Training loss: 4.3936 0.8509 sec/batch
# Epoch 8/10 Iteration: 109200 Avg. Training loss: 4.3205 0.8350 sec/batch
# Epoch 8/10 Iteration: 109300 Avg. Training loss: 4.2290 0.9073 sec/batch
# Epoch 8/10 Iteration: 109400 Avg. Training loss: 4.3580 0.9499 sec/batch
# Epoch 8/10 Iteration: 109500 Avg. Training loss: 4.3535 1.0159 sec/batch
# Epoch 8/10 Iteration: 109600 Avg. Training loss: 4.3273 0.9570 sec/batch
# Epoch 8/10 Iteration: 109700 Avg. Training loss: 4.3992 0.9137 sec/batch
# Epoch 8/10 Iteration: 109800 Avg. Training loss: 4.3360 0.8951 sec/batch
# Epoch 8/10 Iteration: 109900 Avg. Training loss: 4.3579 0.8928 sec/batch
# Epoch 8/10 Iteration: 110000 Avg. Training loss: 4.3075 0.8179 sec/batch
# Nearest to also: which, for, as, that, sometimes, below, frequently, often,
# Nearest to no: little, longer, evidence, never, there, nothing, still, only,
# Nearest to than: more, less, much, smaller, considerably, but, or, larger,
# Nearest to by: in, which, with, to, s, a, for, this,
# Nearest to four: three, five, six, seven, two, eight, nine, zero,
# Nearest to with: to, in, by, when, a, for, which, that,
# Nearest to this: which, another, it, a, that, however, some, an,
# Nearest to more: less, rather, larger, most, fewer, than, better, longer,
# Nearest to nobel: prize, laureate, honors, awarded, academy, physiology, scientist, chromatin,
# Nearest to powers: power, empires, psionic, forces, abilities, policy, parties, institutions,
# Nearest to paris: france, louvre, moscow, lausanne, denis, tienne, europe, london,
# Nearest to experience: experiences, skill, knowledge, direct, experienced, understanding, spiritual, involvement,
# Nearest to bill: pubic, eamon, whisky, supercontinent, cassady, reproduce, toggle, meiji,
# Nearest to operating: unix, hardware, liner, postmaster, rail, windowing, parliamentary, os,
# Nearest to event: events, extinction, era, pri, probability, object, soe, tunguska,
# Nearest to liberal: conservative, party, political, liberals, democratic, social, maclennan, liberalism,
# Epoch 8/10 Iteration: 110100 Avg. Training loss: 3.9239 0.8576 sec/batch
# Epoch 8/10 Iteration: 110200 Avg. Training loss: 4.1293 0.8005 sec/batch
# Epoch 8/10 Iteration: 110300 Avg. Training loss: 4.2163 0.8059 sec/batch
# Epoch 8/10 Iteration: 110400 Avg. Training loss: 4.2665 0.8461 sec/batch
# Epoch 8/10 Iteration: 110500 Avg. Training loss: 4.2867 0.9104 sec/batch
# Epoch 8/10 Iteration: 110600 Avg. Training loss: 4.3213 0.8952 sec/batch
# Epoch 8/10 Iteration: 110700 Avg. Training loss: 4.3971 0.9775 sec/batch
# Epoch 8/10 Iteration: 110800 Avg. Training loss: 4.3306 0.8778 sec/batch
# Epoch 8/10 Iteration: 110900 Avg. Training loss: 4.4206 0.9997 sec/batch
# Epoch 8/10 Iteration: 111000 Avg. Training loss: 4.4158 1.0175 sec/batch
# Nearest to also: which, often, sometimes, as, for, that, below, some,
# Nearest to no: evidence, little, longer, there, nothing, never, that, a,
# Nearest to than: less, more, much, smaller, but, considerably, or, like,
# Nearest to by: in, with, to, which, s, a, this, for,
# Nearest to four: three, five, eight, six, two, seven, nine, zero,
# Nearest to with: by, to, for, in, a, as, that, like,
# Nearest to this: which, it, that, a, some, however, another, same,
# Nearest to more: less, rather, larger, most, fewer, better, than, longer,
# Nearest to nobel: prize, laureate, physiology, awarded, honors, recipient, scientist, writer,
# Nearest to powers: power, abilities, psionic, empires, possess, crowns, piercer, hutton,
# Nearest to paris: france, louvre, denis, lausanne, teau, mus, athens, moscow,
# Nearest to experience: experiences, spiritual, understanding, jimi, gain, experienced, subjective, insight,
# Nearest to bill: pubic, reproduce, bills, watch, commons, ratsiraka, rampton, toggle,
# Nearest to operating: unix, postmaster, consequently, liner, hardware, os, rail, tuck,
# Nearest to event: events, extinction, pri, object, tunguska, staged, occur, era,
# Nearest to liberal: conservative, liberals, maclennan, political, party, eircom, nazi, democrat,
# Epoch 8/10 Iteration: 111100 Avg. Training loss: 4.4090 0.9737 sec/batch
# Epoch 8/10 Iteration: 111200 Avg. Training loss: 4.3774 1.0679 sec/batch
# Epoch 8/10 Iteration: 111300 Avg. Training loss: 4.3378 1.1197 sec/batch
# Epoch 8/10 Iteration: 111400 Avg. Training loss: 4.0958 0.9364 sec/batch
# Epoch 8/10 Iteration: 111500 Avg. Training loss: 4.3854 0.8917 sec/batch
# Epoch 8/10 Iteration: 111600 Avg. Training loss: 4.3856 0.8475 sec/batch
# Epoch 8/10 Iteration: 111700 Avg. Training loss: 4.3094 1.0036 sec/batch
# Epoch 8/10 Iteration: 111800 Avg. Training loss: 4.4178 0.9241 sec/batch
# Epoch 8/10 Iteration: 111900 Avg. Training loss: 4.3538 0.8340 sec/batch
# Epoch 8/10 Iteration: 112000 Avg. Training loss: 4.4402 0.8255 sec/batch
# Nearest to also: which, as, for, often, sometimes, several, below, some,
# Nearest to no: evidence, there, longer, nothing, little, never, only, still,
# Nearest to than: much, less, more, but, smaller, considerably, or, slightly,
# Nearest to by: which, this, in, with, that, for, to, also,
# Nearest to four: two, three, five, six, eight, zero, seven, nine,
# Nearest to with: to, by, in, that, which, when, for, a,
# Nearest to this: which, a, it, that, another, however, same, to,
# Nearest to more: less, rather, larger, most, than, better, fewer, much,
# Nearest to nobel: prize, laureate, physiology, awarded, recipient, honors, austrian, scientist,
# Nearest to powers: abilities, power, psionic, empires, piercer, forces, possess, slovenes,
# Nearest to paris: france, denis, french, louvre, moscow, mus, mettrie, london,
# Nearest to experience: experiences, spiritual, understanding, gain, involvement, experienced, direct, jimi,
# Nearest to bill: pubic, disappearance, rampton, reproduce, arden, previously, celestines, eamon,
# Nearest to operating: unix, system, hardware, run, systems, electoral, tuck, solaris,
# Nearest to event: events, extinction, object, probability, tunguska, staged, pri, concerts,
# Nearest to liberal: conservative, liberals, colleges, liberalism, japan, maclennan, social, australia,
# Epoch 8/10 Iteration: 112100 Avg. Training loss: 4.3590 0.8810 sec/batch
# Epoch 8/10 Iteration: 112200 Avg. Training loss: 4.4075 0.8159 sec/batch
# Epoch 8/10 Iteration: 112300 Avg. Training loss: 4.1566 0.8347 sec/batch
# Epoch 8/10 Iteration: 112400 Avg. Training loss: 4.1399 0.8437 sec/batch
# Epoch 8/10 Iteration: 112500 Avg. Training loss: 4.3442 0.7894 sec/batch
# Epoch 8/10 Iteration: 112600 Avg. Training loss: 4.3773 0.8014 sec/batch
# Epoch 8/10 Iteration: 112700 Avg. Training loss: 4.1560 0.7958 sec/batch
# Epoch 8/10 Iteration: 112800 Avg. Training loss: 4.3641 0.7998 sec/batch
# Epoch 8/10 Iteration: 112900 Avg. Training loss: 4.4125 0.8590 sec/batch
# Epoch 8/10 Iteration: 113000 Avg. Training loss: 4.3503 0.8099 sec/batch
# Nearest to also: which, often, below, sometimes, commonly, several, frequently, for,
# Nearest to no: little, longer, evidence, nothing, there, never, still, only,
# Nearest to than: less, much, more, but, considerably, smaller, likely, larger,
# Nearest to by: in, with, which, when, initially, a, to, who,
# Nearest to four: five, three, six, two, seven, eight, zero, nine,
# Nearest to with: to, by, in, which, for, when, had, between,
# Nearest to this: it, another, which, a, that, what, some, same,
# Nearest to more: less, rather, larger, most, better, than, fewer, stronger,
# Nearest to nobel: prize, laureate, recipient, awarded, scientist, physiology, writer, peace,
# Nearest to powers: power, abilities, empires, psionic, piercer, possess, forces, fenwick,
# Nearest to paris: france, london, denis, french, athens, germany, nantes, spain,
# Nearest to experience: experiences, involvement, gain, understanding, something, experienced, reality, direct,
# Nearest to bill: reproduce, pubic, legislation, gyroscope, cindy, ibsen, tapes, antidiscrimination,
# Nearest to operating: system, os, unix, dos, run, systems, version, applications,
# Nearest to event: events, extinction, tunguska, object, probability, staged, meteorite, leisurely,
# Nearest to liberal: conservative, liberals, liberalism, colleges, maclennan, political, echelon, democrat,
# Epoch 8/10 Iteration: 113100 Avg. Training loss: 4.3141 0.8158 sec/batch
# Epoch 8/10 Iteration: 113200 Avg. Training loss: 4.3557 0.7883 sec/batch
# Epoch 8/10 Iteration: 113300 Avg. Training loss: 4.3368 0.7748 sec/batch
# Epoch 8/10 Iteration: 113400 Avg. Training loss: 4.3296 0.8469 sec/batch
# Epoch 8/10 Iteration: 113500 Avg. Training loss: 4.4347 0.8500 sec/batch
# Epoch 9/10 Iteration: 113600 Avg. Training loss: 4.3918 0.2111 sec/batch
# Epoch 9/10 Iteration: 113700 Avg. Training loss: 4.3494 0.8614 sec/batch
# Epoch 9/10 Iteration: 113800 Avg. Training loss: 4.3198 0.7661 sec/batch
# Epoch 9/10 Iteration: 113900 Avg. Training loss: 4.3726 0.7621 sec/batch
# Epoch 9/10 Iteration: 114000 Avg. Training loss: 4.3459 0.8210 sec/batch
# Nearest to also: which, often, sometimes, for, to, that, a, as,
# Nearest to no: there, little, evidence, nothing, only, longer, never, still,
# Nearest to than: much, less, more, but, smaller, considerably, however, larger,
# Nearest to by: in, to, which, a, with, for, that, as,
# Nearest to four: five, three, six, two, eight, seven, nine, zero,
# Nearest to with: by, in, to, for, which, a, that, is,
# Nearest to this: a, it, which, another, that, however, an, same,
# Nearest to more: less, rather, most, larger, better, than, fewer, other,
# Nearest to nobel: prize, laureate, recipient, ipx, awarded, bakkers, lactate, honors,
# Nearest to powers: power, forces, legislation, authority, empires, policy, territories, parties,
# Nearest to paris: france, french, london, denis, abbey, germany, tienne, skyscraper,
# Nearest to experience: experiences, understanding, skill, gain, cause, something, reality, knowledge,
# Nearest to bill: pubic, reproduce, province, antidiscrimination, henry, gyroscope, fails, ibsen,
# Nearest to operating: unix, os, system, electoral, microkernel, systems, dos, users,
# Nearest to event: events, object, extinction, tunguska, meteorite, type, leisurely, televised,
# Nearest to liberal: conservative, liberals, political, liberalism, colleges, democrat, maclennan, echelon,
# Epoch 9/10 Iteration: 114100 Avg. Training loss: 4.2877 0.7949 sec/batch
# Epoch 9/10 Iteration: 114200 Avg. Training loss: 4.3437 0.9012 sec/batch
# Epoch 9/10 Iteration: 114300 Avg. Training loss: 4.3696 0.8603 sec/batch
# Epoch 9/10 Iteration: 114400 Avg. Training loss: 4.2540 0.8204 sec/batch
# Epoch 9/10 Iteration: 114500 Avg. Training loss: 4.2566 0.8948 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
